# %% [markdown]
# <a href="https://colab.research.google.com/github/SRIJANRAOS/srijanraos_INFO5731_spring2026/blob/main/In_class_exercises_1_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **In-Class Assignment — Week 2 (Lesson 2)**
#
# Time: 20–30 minutes
# Points: 10
#
# **Instructions**
#
# This is an individual in-class assignment.
#
# Complete it during class time.
#
# You may use Week 2 lecture notes / demo notebooks.
#
# Write your code under each question and print the output.
#
# Submit the GitHub link.

# %% [markdown]
# ## Question 1 ( 2 point)
# Write a Python program that  prompts the user to input the length and width of a rectangle, and then calculates and displays the area of the rectangle.

# %%
def get_number(prompt):
    while True:
        try:
            value = float(input(prompt))
            return value
        except ValueError:
            print("Please enter a valid number.")


length = get_number("Enter the length of the rectangle: ")
width = get_number("Enter the width of the rectangle: ")


area = length * width


print("The area of the rectangle is:", area)
# Out:
# The area of the rectangle is: 15.0

# %% [markdown]
# ## Question 2 ( 2 point)
# Create a Python program that interactively takes two numerical inputs from the user and swaps their values without utilizing an extra variable.

# %%
a = float(input("Enter the first number: "))
b = float(input("Enter the second number: "))

a, b = b, a

print("After swapping:")
print("First number:", a)
print("Second number:", b)
# Out:
# After swapping:
# First number: 4.0
# Second number: 6.0

# %% [markdown]
# ## Question 3 ( 2 point)
# Write a Python script to determine and print the length of a user-input string.

# %%
text = input("Enter a string: ")


print("Length of the string:", len(text))
# Out:
# Length of the string: 1

# %% [markdown]
# ## Question 4 ( 2 point)
# Design a Python function to check if a number is prime.

# %%
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True


num = int(input("Enter a number: "))
if is_prime(num):
    print(num, "is a prime number")
else:
    print(num, "is not a prime number")
# Out:
# 5 is a prime number

# %% [markdown]
# ## Question 5 ( 2 point)
# Write a Python program to concatenate following dictionaries to create a new one.
#
# Sample Dictionary : dic1={1:10, 2:20}, dic2={3:30, 4:40}, dic3={5:50,6:60},
#
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
dic1 = {1: 10, 2: 20}
dic2 = {3: 30, 4: 40}
dic3 = {5: 50, 6: 60}


result = {}
result.update(dic1)
result.update(dic2)
result.update(dic3)


print(result)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}
